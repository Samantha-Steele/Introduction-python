# %% [markdown]
# <a href="https://colab.research.google.com/github/Samantha-Steele/Introduction-python/blob/master/Week_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
import urllib.request

def count_lines(file_name):
  my_file = urllib.request.urlopen(file_name)
  line_count = 0
  for line in my_file:
    line_count = line_count + 1
    answer = line_count
  print("First file number of lines:" , answer)

file_name =  "https://raw.githubusercontent.com/mlepinski/Python-Worksheets/master/Sonnets.txt"
answer = answer1
line_count = line_count1
answer1 = line_count1
(count_lines(file_name))

file_name = "https://raw.githubusercontent.com/mlepinski/Python-Worksheets/master/coolWords.txt"
answer = answer2
line_count = line_count2
answer2 = line_count2
(count_lines(file_name))

#2
def lines_with_word(file_name, the_choosen_one):
  file_name =  "https://raw.githubusercontent.com/mlepinski/Python-Worksheets/master/Sonnets.txt"
  my_file = urllib.request.urlopen(file_name)
  word_count = 0
  for line in my_file:
    line = line.decode("utf-8")
    if the_choosen_one in line:
      word_count = word_count + 1
  print(word_count)
the_choosen_one = input("Enter a word to search for: ")
lines_with_word(file_name, the_choosen_one)

#3
def lines_with_word_l(file_name, the_choosen_one):
  file_name =  "https://raw.githubusercontent.com/mlepinski/Python-Worksheets/master/Sonnets.txt"
  my_file = urllib.request.urlopen(file_name)
  long_string = my_file.read()
  long_string = long_string.decode("utf-8")
  no_line_breaks = long_string.replace("\n", " ")
  words = long_string.split()
  word_count = 0
  for line in words:
    line = line.lower()
    if the_choosen_one in line:
      word_count = word_count + 1
  print(word_count)
the_choosen_one = input("Enter a word to search for: ")
lines_with_word_l(file_name, the_choosen_one)

#4
def words_in_text(file_name, the_choosen_one):
  file_name =  "https://raw.githubusercontent.com/mlepinski/Python-Worksheets/master/Sonnets.txt"
  my_file = urllib.request.urlopen(file_name)
  long_string = my_file.read()
  long_string = long_string.decode("utf-8")
  no_line_breaks = long_string.replace("\n", " ")
  words = no_line_breaks.split()
  word_count = 0
  for word in words:
    word = word.lower()
    if the_choosen_one == word:
      word_count = word_count + 1
  print(word_count)
the_choosen_one = input("Enter a word to search for: ")
words_in_text(file_name, the_choosen_one)

#5
def words_in_text_improved(file_name, the_choosen_one):
  file_name =  "https://raw.githubusercontent.com/mlepinski/Python-Worksheets/master/Sonnets.txt"
  my_file = urllib.request.urlopen(file_name)
  long_string = my_file.read()
  long_string = long_string.decode("utf-8")
  no_line_breaks = long_string.replace("\n", " ")
  new_string1 = no_line_breaks.replace(",", "")
  new_string2 = new_string1.replace(".", "")
  new_string3 = new_string2.replace("'", "")
  new_string4 = new_string3.replace("?", "")
  new_string5 = new_string4.replace("!", "")
  new_string6 = new_string5.replace(";", "")
  new_string7 = new_string6.replace(":", "")
  words = new_string7.split()
  word_count = 0
  for word in words:
    word = word.lower()
    if the_choosen_one == word:
      word_count = word_count + 1
  print(word_count)
the_choosen_one = input("Enter a word to search for: ")
words_in_text_improved(file_name, the_choosen_one)

#6
def word_frequency(file_name, the_choosen_one):
  file_name =  "https://raw.githubusercontent.com/mlepinski/Python-Worksheets/master/Sonnets.txt"
  my_file = urllib.request.urlopen(file_name)
  long_string = my_file.read()
  long_string = long_string.decode("utf-8")
  no_line_breaks = long_string.replace("\n", " ")
  new_string1 = no_line_breaks.replace(",", "")
  new_string2 = new_string1.replace(".", "")
  new_string3 = new_string2.replace("'", "")
  new_string4 = new_string3.replace("?", "")
  new_string5 = new_string4.replace("!", "")
  new_string6 = new_string5.replace(";", "")
  new_string7 = new_string6.replace(":", "")
  words = new_string7.split()
  word_count = 0
  for word in words:
    word = word.lower()
    if the_choosen_one == word:
      word_count = word_count + 1
  print(word_count)
  word_counter = 0
  words_in_text_improved(file_name, the_choosen_one)
  for word in words:
    word = word.lower()
    word_counter = word_counter + 1
    total_words = word_counter
  print(total_words)
  frequency = int(word_count) / int(total_words)
  frequency100 = frequency * 100
  print(frequency100)
word_frequency(file_name, the_choosen_one)
# Out:
# First file number of lines: 2617
# First file number of lines: 718
# Enter a word to search for: the
# 724
# Enter a word to search for: the
# 987
# Enter a word to search for: the
# 444
# Enter a word to search for: the
# 444
# 444
# 444
# 17667
# 2.5131601290541687
